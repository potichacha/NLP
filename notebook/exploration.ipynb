# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "source": [
    "# 📊 Exploration Notebook\n",
    "Notebook pour explorer les données et tester rapidement les modèles NLP entraînés."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 1,
   "source": [
    "# Imports\n",
    "import joblib\n",
    "import pandas as pd\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "from sklearn.metrics import ConfusionMatrixDisplay, classification_report"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 2,
   "source": [
    "# Charger un modèle entraîné (choisir parmi naive_bayes, random_forest, linear_svm)\n",
    "model_name = 'naive_bayes'\n",
    "model_path = f'../models/classifier_{model_name}.joblib'\n",
    "\n",
    "model = joblib.load(model_path)\n",
    "model"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 3,
   "source": [
    "# Exemple de prédiction rapide\n",
    "example_text = [\"Préchauffez votre four à 180 degrés et mélangez les œufs avec la farine.\"]\n",
    "predicted = model.predict(example_text)\n",
    "print(f\"Catégorie prédite : {predicted[0]}\")"
   ]
  },
  {
   "cell_type": "markdown",
   "source": [
    "## Évaluation rapide du modèle sur tout le jeu de test"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 4,
   "source": [
    "# Charger et préparer les données pour l'évaluation complète\n",
    "from src.config import DATA_DIR, TEST_SIZE, RANDOM_STATE\n",
    "from src.data import load_data\n",
    "from src.preprocess import preprocess_text\n",
    "from sklearn.model_selection import train_test_split\n",
    "\n",
    "texts, labels = load_data(DATA_DIR)\n",
    "texts = [preprocess_text(text) for text in texts]\n",
    "\n",
    "_, X_test, _, y_test = train_test_split(\n",
    "    texts, labels, test_size=TEST_SIZE, random_state=RANDOM_STATE\n",
    ")\n",
    "\n",
    "predictions = model.predict(X_test)\n",
    "\n",
    "print(classification_report(y_test, predictions))"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 5,
   "source": [
    "# Afficher la matrice de confusion\n",
    "fig, ax = plt.subplots(figsize=(10, 8))\n",
    "ConfusionMatrixDisplay.from_estimator(model, X_test, y_test, ax=ax, cmap='Blues', xticks_rotation='vertical')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "version": "3.x"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 5
}
